# %%
import pandas as pd
import numpy as np

import sklearn as sns

# %%
data_path = '~/Documents/Data/'
data_file = 'wines.csv'

# %%
wine_df = pd.read_csv(data_path+data_file)

# %%
wine_df.head()
# Out:
#   Vintage   Country                           County         Designation  \
# 0  1/1/19     Spain                             Cava  1919 Brut Selecció
# 1  1/1/29     Italy       Vernaccia di San Gimignano                 NaN
# 2  1/1/29     Italy  Sangiovese di Romagna Superiore            Prugneto
# 3  1/1/34  Portugal                              NaN       Reserva Velho
# 4  1/1/45    France                       Rivesaltes      Legend Vintage
#
#    Points    Price              Province  \
# 0      88   $13.00             Catalonia
# 1      87   $14.00               Tuscany
# 2      84   $15.00         Central Italy
# 3      93  $495.00               Colares
# 4      95  $350.00  Languedoc-Roussillon
#
#                                                Title          Variety  \
# 0     L'Arboc NV 1919 Brut Selecció Sparkling (Cava)  Sparkling Blend
# 1         Guidi 1929 2015 Vernaccia di San Gimignano        Vernaccia
# ...
